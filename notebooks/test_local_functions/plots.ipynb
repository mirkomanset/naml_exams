# %%
# %load_ext autoreload
# %autoreload 2
import os

while not os.getcwd().endswith("naml_exams"):
    os.chdir("..")

# %% [markdown]
# # Imports

# %%
import numpy as np
from scripts.utils_exercise_2 import plot_surface, plot_contour, plot_optimization_2d

# %% [markdown]
# # Try the plot functions

# %%
def quadratic_bowl(x, y):
    return x**2 + y**2

def rosenbrock(x, y):
    return (1 - x)**2 + 100 * (y - x**2)**2

def himmelblau(x, y):
    return (x**2 + y - 11)**2 + (x + y**2 - 7)**2

# %% [markdown]
# ## Surface

# %%
plot_surface(quadratic_bowl, -5, 5, 100)

# %%
plot_surface(rosenbrock, -5, 5, 100)

# %%
plot_surface(himmelblau, -5, 5, 100)

# %% [markdown]
# ## Contour

# %%
# Sample x_history for contour plotting
x_history = [np.array([i/10, i/10]) for i in range(-20, 21)]  # A line trajectory as an example

# %%
plot_contour(quadratic_bowl, x_history)

# %%
plot_contour(rosenbrock, x_history)

# %%
plot_contour(himmelblau, x_history)
